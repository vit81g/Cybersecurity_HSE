# %% [markdown]
# # Вебинар 4. Функции и области видимости

# %% [markdown]
# ## Проверка связи

# %% [markdown]
# Если у вас нет звука:
# *   убедитесь, что на вашем устройстве и в колонках включён звук
# *   обновите страницу вебинара или закройте страницу и заново присоединитесь к вебинару
# *   откройте вебинар в другом браузере
# *   перезагрузите ваше устройство и попытайтесь войти снова

# %% [markdown]
# Поставьте в чат:
# * «+» — если видно и слышно
# * «–» — если нет

# %% [markdown]
# ## О спикере

# %% [markdown]
# **Глеб Пехов**
# *   Бэкенд-разработчик на Python
# *   Опыт разработки — 4 года

# %% [markdown]
# ## Правила участия

# %% [markdown]
# *   Приготовьте блокнот и ручку, чтобы записывать важные мысли и идеи
# *   Продолжительность вебинара — 80 минут
# *   Вы можете писать свои вопросы в чате или задавать их вслух
# *   Запись вебинара будет доступна в личном кабинете

# %% [markdown]
# ## Цели занятия

# %% [markdown]
# *   Изучить на практике, как прописывают функции в реальном коде
# *   Изучить на практике, как работать с областями видимости
# *   Узнать, как работать с lambda-функцией
# *   Применить на практике функции map, filte_r, reduce
# *   Попрактиковаться в решении задач на реализацию функций

# %% [markdown]
# ## План занятия

# %% [markdown]
# 1. Функции
# 2. Области видимости
# 3. Lambda-функции
# 4. Функции map, filte_r, reduce
# 5. Решение задач
# 6. Домашнее задание

# %% [markdown]
# # Функции

# %%
# Создаём функцию
def square(number):
    result = number ** 2
    return result

# print(square(10))
my_square = square(10)
print(my_square)
# Out:
# 100

# %%
# Пишем docstring к своей функции
def square(number):
    """
    this is my function
    """
    result = number ** 2
    return result

# %%
# Функция без параметров
def square_2():
    user_input = int(input('Введите число'))
    result = user_input ** 2
    return result

square_2()
# Out:
# Введите число9
# 81

# %%
# Функция с двумя параметрамим
def power(number, number_2):
    result = number ** number_2
    return result

power(4, 10)
# Out:
# 1048576

# %%
# Функция с параметром по умолчанию
def power(number, number_2=2):
    result = number ** number_2
    return result

power(10)
# Out:
# 100

# %%
# Если не указан return, функция всегда возвращает None
def square_3(number):
    result = number ** 2
    print(result)
#     return None
#     return
print(square_3(5))
# Out:
# 25
# None

# %% [markdown]
# ## Ваши вопросы

# %% [markdown]
# ### Области видимости

# %%
number = 5
power = 3

def power_2():
    number = 6
    power = 2
    return number ** power

print(power_2())
print(number ** power)
# Out:
# 36
# 125

# %%
number = 5
power = 3

def power_2():
    number = 6
    return number ** power

print(power_2())
print(number ** power)
# Out:
# 216
# 125

# %%
number = 5
power = 3

def power_2():
    return number ** power

power_2()
# Out:
# 125

# %%
def power_2():
    number = 6
    power = 2
    some_number = 1
    return number ** power

print(some_number)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 7
#       4     some_number = 1
#       5     return number ** power
# ----> 7 print(some_number)
#
# NameError: name 'some_number' is not defined

# %%
# global

name = 'James'
def say_hi():
    global name
    name = 'Oleg'
    print('Hello', name)

say_hi()

print(name)
# Out:
# Hello Oleg
# Oleg

# %% [markdown]
# ## Ваши вопросы

# %% [markdown]
# ### Lambda-функции

# %%
def func(x, y):
    return x + y

# %%
func = lambda x, y: x + y

# %%
func = lambda x, y: x + y
func(1, 6)
# Out:
# 7

# %%
nums = [1, 2, 3, 4, 5]

# %%
# even_numbers = lambda x: x % 2 == 0
odd_even_numbers = lambda x: 'even' if x % 2 == 0 else 'odd'

# %%
for num in nums:
#     print(even_numbers(num))
    print(odd_even_numbers(num))
# Out:
# odd
# even
# odd
# even
# odd

# %% [markdown]
# ## Ваши вопросы

# %% [markdown]
# ### Функции map, filte_r, reduce

# %% [markdown]
# #### Map

# %%
# Функция map
something = [1, 2, 3, 4, 5]

def add_two(num):
    return num + 2

print([*(map(add_two, something))])

# Альтернатива

def add_two_to_list(nums):
    buffer = []
    for i in nums:
        buffer.append(i+2)
    return buffer

print(add_two_to_list(something))
# Out:
# [3, 4, 5, 6, 7]
# [3, 4, 5, 6, 7]

# %%
def square(x):
    return x**2

list(map(square, something))
# Out:
# [1, 4, 9, 16, 25]

# %% [markdown]
# #### Filte_r

# %%
def is_valid(num):
    return num > 4

result = [1, 2, 3, 4, 5, 6, 7, 8, 9]

print([*(filter(is_valid, result))])
# Out:
# [5, 6, 7, 8, 9]

# %% [markdown]
# #### Reduce

# %%
from functools import reduce

def add(x, y):
    return x + y

def multiply(x, y):
    return x * y

numbers = [1, 2, 3, 4, 5]
result = reduce(add, numbers, 0)
print(result)
# 15

result = reduce(multiply, numbers, 1)
print(result)
# Out:
# 15
# 120

# %% [markdown]
# ### Args and kwargs

# %%
def api_request(*params):
    date_start = params[0]
    date_end = params[1]
    print(params)
    print(date_start, date_end)

# %%
api_request('2019-01-01', '2019-01-31', ';sdfsdgsdg', 'sdgsdgsdg', 'sdgsdg')
# Out:
# ('2019-01-01', '2019-01-31', ';sdfsdgsdg', 'sdgsdgsdg', 'sdgsdg')
# 2019-01-01 2019-01-31

# %%
def api_requets(**params):
    return params

# %%
api_requets(a=1, b=2, c=3, date='2020-01-01')
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'date': '2020-01-01'}

# %%
def api_request(**params):
    date_start = params['date_start']
    date_end = params['date_end']
    print(params)
    print(date_start, date_end)

# %%
api_request(date_start='2019-01-31', report='traffic', date_end='2019-01-01')
# Out:
# {'date_start': '2019-01-31', 'report': 'traffic', 'date_end': '2019-01-01'}
# 2019-01-31 2019-01-01

# %%
# Вынесем классификацию возраста в отдельную функцию
def age_classification(age):
    """
    Возвращает возрастную категорию для возраста age (можно передать как строку).
    Классификация категорий:
        - до 18 лет - children
        - 19-60 - young
        - старше 65 - retiree

    Пример
    age_classification('18')
    'children'

    age_classification(65)
    'retiree'
    """

    if int(age) <= 18:
        return 'children'
    elif int(age) <= 65:
        return 'young'
    elif int(age) > 65:
        return 'retiree'
    return 'boom'

# %% [markdown]
# ## Ваши вопросы

# %% [markdown]
# ## Решаем задачи

# %% [markdown]
# Реализуйте функцию print_motto(), которая печатает на экран фразу Winter is coming.

# %% [markdown]
# Реализуйте функцию say_hurray_three_times(), которая возвращает строку hurray! hurray! hurray!

# %% [markdown]
# Реализуйте функцию truncate(), которая должна обрезать переданную строку до указанного количества символов,
# добавлять в конце многоточие и возвращать получившуюся строку.
# Подобная логика часто используется на сайтах, чтобы отобразить длинный текст в сокращённом виде.
#
# Функция принимает два параметра:
#
#
# *   строка, которую нужно обрезать (параметр text)
# *   число символов, которые нужно оставить (параметр length)
#
#
# Пример того, как должна работать написанная вами функция:
#
# *   передаём текст напрямую
# *   обрезаем текст, оставляя 2 символа
# truncate('hexlet', 2)  'he...'
# *   через переменную text = 'it works!' обрезаем текст, оставляя 4 символа
# truncate(text, 4)  'it w...'

# %% [markdown]
# Реализуйте функцию get_hidden_card(), которая:
#
# *   принимает на вход номер кредитки (состоящий из 16 цифр) в виде строки
# *   возвращает его скрытую версию, которую можно использовать на сайте для отображения
#
# Если исходная карта имела номер 2034399002125581, то скрытая версия выглядит так: ****5581.
# Другими словами, функция берёт последние 4 символа номера карты и добавляет перед ними звёздочки.
# Количество звёздочек регулируется вторым необязательным параметром. Значение по умолчанию — 4.

# %% [markdown]
# ## Ваши вопросы

# %% [markdown]
# ### Домашнее задание

# %% [markdown]
# 1. Реализуйте функцию sum_distance(from, to), которая суммирует все числа от значения from до величины to включительно.
# Если пользователь задаст первое число больше, чем второе, просто поменяйте их местами.

# %% [markdown]
# 2. Реализуйте функцию trim_and_repeat(), которая принимает три параметра:
#
# *   строку
# *   offset — число символов, на которое нужно обрезать строку слева
# *   repetitions — сколько раз нужно повторить строку перед возвратом получившейся строки
#
# Число символов для среза по умолчанию равно 0, а количество повторений по умолчанию равно 1.
#
# Функция должна возвращать полученную строку.

# %% [markdown]
# ## Итоги занятия

# %% [markdown]
# Поработали с функциями и областями видимости, узнали об особенностях работы с функциями lambda-функции, map, filte_r, reduce, попрактиковались в решении задач.
