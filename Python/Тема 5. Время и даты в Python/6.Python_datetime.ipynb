# %% [markdown]
# # Вебинар 6. Даты, время, обработка ошибок

# %% [markdown]
# ## Проверка связи

# %% [markdown]
# Если у вас нет звука:
# *   убедитесь, что на вашем устройстве и в колонках включён звук
# *   обновите страницу вебинара или закройте страницу и заново присоединитесь к вебинару
# *   откройте вебинар в другом браузере
# *   перезагрузите ваше устройство и попытайтесь войти снова

# %% [markdown]
# Поставьте в чат:
# * «+» — если видно и слышно
# * «–» — если нет

# %% [markdown]
# ## О спикере

# %% [markdown]
# **Глеб Пехов**
# *   Бэкенд-разработчик на Python
# *   Опыт разработки — 4 года

# %% [markdown]
# ## Правила участия

# %% [markdown]
# *   Приготовьте блокнот и ручку, чтобы записывать важные мысли и идеи
# *   Продолжительность вебинара — 80 минут
# *   Вы можете писать свои вопросы в чате или задавать их вслух
# *   Запись вебинара будет доступна в личном кабинете

# %% [markdown]
# ## Цели занятия

# %% [markdown]
# *   Изучить на практике, как работать с датами в Python
# *   Рассмотреть классы date, time, datetime
# *   Изучить на практике, как выполнить прибавление интервала к датам
# *   Разобрать формат unixtime
# *   Разобрать, как работать с основными типами ошибок в Python

# %% [markdown]
# ## План занятия

# %% [markdown]
# 1. Даты
# 2. Обработка ошибок

# %% [markdown]
# # Даты

# %% [markdown]
# ### Модуль Datetime

# %%
# Можно импортировать весь модуль
import datetime

# %%
# Можно импортировать синоним
import datetime as dt

# %%
# Либо импортировать только используемое
from datetime import datetime, date

# %% [markdown]
# ### Поговорим про класс date

# %%
import datetime

# date(year, month, day)
yesterday = datetime.date(2023,12, 7)
print(yesterday)
print(type(yesterday))
# Out:
# 2023-12-07
# <class 'datetime.date'>

# %%
import datetime

# date(year, month, day)
yesterday = datetime.date(2023,12, 07) # Важно что не нужны 0.
print(yesterday)
print(type(yesterday))
# Out:
#   Cell In[42], line 4
#     yesterday = datetime.date(2023,12, 07) # Важно что не нужны 0.
#                                        ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
# можем получить текущую дату
from datetime import date

today = date.today()
print(today)
# Out:
# 2023-12-08

# %% [markdown]
# ### Класс time

# %%
from datetime import time

current_time = time() # В конструктор можно передавать параметры, а можно не передавать.
print(current_time) # По умолчанию получим 00

current_time = time(20, 21, 10)
print(current_time)

current_time = time(20, 21, 10)
print(current_time)
# Out:
# 00:00:00
# 20:21:10
# 20:21:10

# %% [markdown]
# ### Класс datetime

# %%
from datetime import datetime

deadline = datetime(2023, 12, 8)
print(deadline)

deadline = datetime(2023, 12, 9, 4, 30)
print(deadline)
# Out:
# 2023-12-08 00:00:00
# 2023-12-09 04:30:00

# %%
# Очень часто пользуются логикой получения текущего времени.
from datetime import datetime

now = datetime.now()
print(now)

print(now.date())
print(now.time())
# Out:
# 2023-12-08 17:12:39.088376
# 2023-12-08
# 17:12:39.088376

# %%
date_string = '09.05.2018  09:00'

# %%
# сейчас date_string это просто строка
type(date_string)
# Out:
# str

# %% [raw]
# Для определения формата мы можем использовать следующие коды:
# %d: день месяца в виде числа
# %m: порядковый номер месяца
# %y: год в виде 2-х чисел
# %Y: год в виде 4-х чисел
# %H: час в 24-х часовом формате
# %M: минута
# %S: секунда

# %%
datetime.strptime('09.05.2018 09:00', '%d.%m.%Y %H:%M')
# Out:
# datetime.datetime(2018, 5, 9, 9, 0)

# %%
date_datetime = datetime.strptime( date_string, '%d.%m.%Y %H:%M' )
date_datetime
# Out:
# datetime.datetime(2018, 5, 9, 9, 0)

# %%
# теперь можем работать с датами
type(date_datetime)
# Out:
# datetime.datetime

# %%
# получить номер года и часа
date_datetime.year, date_datetime.hour
# Out:
# (2018, 9)

# %%
# день недели
date_datetime.weekday()
# Out:
# 2

# %%
# сегодня
datetime.now()
# Out:
# datetime.datetime(2023, 12, 8, 16, 58, 45, 251312)

# %% [markdown]
# ### Прибавление интервала к датам

# %%
from datetime import timedelta

# %%
start_date = '2018-01-01'
end_date = '2018-01-07'

# %%
type(start_date)
# Out:
# str

# %%
start_date_datetime = datetime.strptime(start_date, '%Y-%m-%d')
start_date_datetime
# Out:
# datetime.datetime(2018, 1, 1, 0, 0)

# %%
start_date_datetime + timedelta(days=1)
# Out:
# datetime.datetime(2018, 1, 2, 0, 0)

# %%
start_date_datetime + timedelta(days=-7, minutes=-1)
# Out:
# datetime.datetime(2017, 12, 24, 23, 59)

# %% [markdown]
# ### Перевод обратно в строку

# %%
date = datetime(2018, 9, 1)
date
# Out:
# datetime.datetime(2018, 9, 1, 0, 0)

# %%
date.strftime('%Y-%m-%d')
# Out:
# '2018-09-01'

# %%
date.strftime('%B %d %Y %I:%M%p')
# Out:
# 'September 01 2018 12:00AM'

# %%
datetime.now().strftime('%Y-%m-01')
# Out:
# '2023-12-01'

# %%
# как получить первый день месяца

date.strftime('%Y-%m-01')
# Out:
# '2018-09-01'

# %%
start_date = '2018-01-01'
end_date = '2018-01-07'

# %%
start_date, end_date
# Out:
# ('2018-01-01', '2018-01-07')

# %%
start_date_dt = datetime.strptime(start_date, '%Y-%m-%d')
end_date_dt = datetime.strptime(end_date, '%Y-%m-%d')

print(start_date_dt, end_date_dt)
# Out:
# 2018-01-01 00:00:00 2018-01-07 00:00:00

# %%
current_dt = start_date_dt

while current_dt <= end_date_dt:
    print(current_dt.strftime('%Y-%m-%d'))

    current_dt += timedelta(days=1)
# Out:
# 2018-01-01
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-06
# 2018-01-07

# %%
current_dt = start_date_dt

while current_dt.strftime('%Y-%m-%d') <= end_date:
    print(current_dt.strftime('%Y-%m-%d'))

    current_dt += timedelta(days=1)
# Out:
# 2018-01-01
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-06
# 2018-01-07

# %%
# можно и с помощью list comprehension
[(start_date_dt + timedelta(days=x)).strftime('%Y-%m-%d') for x in range(10)]
# Out:
# ['2018-01-01',
#  '2018-01-02',
#  '2018-01-03',
#  '2018-01-04',
#  '2018-01-05',
#  '2018-01-06',
#  '2018-01-07',
#  '2018-01-08',
#  '2018-01-09',
#  '2018-01-10']

# %% [markdown]
# ###  Unixtime
# Количество секунд, прошедших с 1 января 1970 года по UTC

# %%
import time
from datetime import date
from datetime import datetime

# %%
d = date(2019, 3, 11)

unixtime = time.mktime(d.timetuple())
unixtime

# %%
from datetime import datetime

# %%
datetime.fromtimestamp(1552251600)

# %% [markdown]
# На практике все сложнее https://habr.com/ru/post/452584/

# %% [markdown]
# ## Ваши вопросы

# %% [markdown]
# # Обработка ошибок
# 1. Текст ошибки указывается в последней строчке
# 2. Все что перед ней - место, где ошибка произошла
# 3. Есть встроенные типы ошибок, но можно создавать и свои

# %% [markdown]
# Некоторые типы ошибок из документации:
# - ZeroDivisionError - деление на ноль
# - ImportError - не удалось импортирование модуля или его атрибута (надо установить эту библиотеку)
# - IndexError - индекс не входит в диапазон элементов.
# - KeyError - несуществующий ключ (в словаре, множестве или другом объекте)
# - MemoryError - недостаточно памяти
# - SyntaxError - синтаксическая ошибка (вы опечатались или не закрыли скобку)
# - TypeError - операция применена к объекту несоответствующего типа
# - ValueError - функция получает аргумент правильного типа, но некорректного значения

# %%
# эту строку можно перевести в число
some_num = '123'

# %%
float(some_num)

# %%
# а эту уже нет (по крайней мере в десятичном счислении)
ups = '123a'

# %%
# ValueError - тип ошибки, далее пояснение что произошло
# ----> 1 float(ups) - в каком месте кода произошла ошибка
float(ups)

# %% [markdown]
# Пример ошибки внутри функции

# %%
def square_sum(*args):
    total_sum = 0
    for arg in args:
        total_sum += arg**2

    return total_sum

# %%
square_sum(1, 2, 3)

# %%
# пытаемся применить к операцию возведения в квадрат к строке
# ----> 1 square_sum(1, 2, '3') - в какой функции произошла ошибка
# ----> 4         total_sum += arg**2 - в какой именно строке произошла ошибка

square_sum(1, 2, '3')

# %% [markdown]
# Как сделать, чтобы цикл с расчетом не падал каждый раз

# %%
try:
    # ваш код, где может произойти ошибка
    float('123a')

except:
    # код, который выполняется в случае ошибки

# %%
data = ['90', '60', '90', '240tot']
total_sum = 0

for num in data:
    try:
        total_sum += float(num)

    except:
        print('Ошибка в данных: {}'.format(num))

print('Итого', total_sum)

# %% [markdown]
# Как сохранить всю информацию об ошибке?

# %%
# полная версия traceback
import traceback

try:
    float('123fff')

except Exception:
    print(traceback.print_exc())

print('Проехали')

# %% [markdown]
# ### Блок finally

# %%
try:
    print(stats["wednesday"])

except IndexError:
    print("Ошибка индекса")

except KeyError:
    print("Ошибка ключа")
    print(1/0)

finally:
    print('Эта строчка будет выполнена всегда')

# %% [markdown]
# ## Ваши вопросы

# %% [markdown]
# ## Итоги занятия

# %% [markdown]
# 1. Изучили на практике как работать с классами date, time, datetime и как выполнить прибавление интервала к датам.
# 2. Рассмотрели формат unixtime, как альтернативу datetime
# 3. Рассмотрели типичные проблемы со временем, ведущие к ошибкам при обработке
# и интерпретации данных и поработали с основными типами ошибок в Python.
